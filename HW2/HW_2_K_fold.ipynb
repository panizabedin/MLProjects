# %%
from keras.datasets import cifar10
import tensorflow as tf
from tensorflow import keras
import numpy as np
import math
import matplotlib.pyplot as plt
from keras.utils.np_utils import to_categorical
from keras import layers
from keras import models
from keras import optimizers
from time import time as t
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
# loading CIFAR10 data
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# normalizing data
train_images = train_images.reshape((50000, 32, 32, 3)) / 255.0
test_images = test_images.reshape((10000, 32, 32, 3)) / 255.0

# %%
# m is the number of training examples
m = train_images.shape[0]
shuffled_indices = np.random.permutation(m)
# shuffling the training data randomely
train_images_shuffled = train_images[shuffled_indices]
train_labels_shuffled = train_labels[shuffled_indices]

# setting 0.20 of the training data to validation set randomly


# one hot encoding of the labels
train_labels_shuffled = to_categorical(train_labels_shuffled, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)

# %% [markdown]
# ## K - Fold Validation

# %%
# training function for each fold using data augmentation 
def fold(model, training_set, training_labels, validation_set, validation_set_labels):
    train_datagen = ImageDataGenerator(
        rotation_range=10,
        width_shift_range=0.2,  
        height_shift_range=0.2,   
        shear_range=0.2,        
        horizontal_flip=True)  

    validation_datagen = ImageDataGenerator()

    train_generator = train_datagen.flow(training_set, training_labels, batch_size=32)
    validation_generator = validation_datagen.flow(validation_set, validation_set_labels, batch_size=32)
    history_dataaug_model5 = model.fit_generator(train_generator, validation_data=validation_generator,
                                                 validation_steps=len(training_set) / 32,
                                                 steps_per_epoch=len(training_set) / 32,
                                                 epochs=30, verbose=2)

    score = model.evaluate(validation_set, validation_set_labels, batch_size=128, verbose=0)
    return score[1]

# %%
# Using the winner architecture (arch 5) for training the data in each fold and storing the score 
def k_fold_validation(training_set, training_labels, n):
    # scores stores the accuracy of 5 folds
    scores = []

   
    fold_size = math.floor(len(training_set) / n)
    for i in range(n):
        print("---------- Fold", i+1, "----------")
        fold_validation_set = training_set[i * fold_size:i * fold_size + fold_size]
        fold_validation_set_labels = training_labels[i * fold_size:i * fold_size + fold_size]
        fold_training_set = np.delete(training_set, slice(i * fold_size, i * fold_size + fold_size), axis=0)
        fold_training_labels = np.delete(training_labels, slice(i * fold_size, i * fold_size + fold_size), axis=0)
        model_5 = models.Sequential()
        #CNN layers
        #1
        model_5.add(layers.Conv2D(128, (3, 3), activation = 'relu', input_shape = (32, 32, 3)))
        #2
        model_5.add(layers.Conv2D(256, (3, 3), activation = 'relu'))
        #3
        model_5.add(layers.Conv2D(256, (3, 3), activation = 'relu', strides = 2))
        #4
        model_5.add(layers.Conv2D(256, (3, 3), activation = 'relu'))
        #5
        model_5.add(layers.Conv2D(512, (3, 3), activation = 'relu', strides=2))
        #6
        model_5.add(layers.Conv2D(512, (3, 3), activation = 'relu'))

        #Dense layers
        model_5.add(layers.Flatten())
        #Dropout
        model_5.add(layers.Dropout(0.5))
        model_5.add(layers.Dense(256, activation = 'relu'))
        #batch normalization added
        model_5.add(layers.normalization.BatchNormalization())
        model_5.add(layers.Dense(10, activation = 'softmax'))

        model_5.summary()

        model_5.compile(optimizer='rmsprop',
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])
        # score of each fold
        s = fold(model_5, fold_training_set, fold_training_labels, fold_validation_set, fold_validation_set_labels)

        scores.append(s)

    print(scores)
    
    # computes the average of 5 accuracies for 5 folds
    scores_average = np.average(scores)
    print("Average scores =", scores_average)


k_fold_validation(train_images_shuffled, train_labels_shuffled, 5)
# Out:
# ---------- Fold 1 ----------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 256)       295168
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 256)       590080
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 5, 5, 512)         1180160
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 512)         2359808
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 6,202,378
# Trainable params: 6,201,866
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/30
#  - 30s - loss: 2.0327 - acc: 0.2462 - val_loss: 1.9958 - val_acc: 0.2749
# Epoch 2/30
#  - 28s - loss: 1.7596 - acc: 0.3462 - val_loss: 1.4659 - val_acc: 0.4549
# Epoch 3/30
#  - 29s - loss: 1.6138 - acc: 0.4074 - val_loss: 1.4293 - val_acc: 0.4871
# Epoch 4/30
#  - 29s - loss: 1.4961 - acc: 0.4575 - val_loss: 1.6053 - val_acc: 0.4510
# Epoch 5/30
#  - 29s - loss: 1.3913 - acc: 0.5020 - val_loss: 1.2945 - val_acc: 0.5458
# Epoch 6/30
#  - 29s - loss: 1.3119 - acc: 0.5309 - val_loss: 1.3023 - val_acc: 0.5547
# Epoch 7/30
#  - 28s - loss: 1.2435 - acc: 0.5600 - val_loss: 1.5165 - val_acc: 0.5317
# Epoch 8/30
#  - 29s - loss: 1.1799 - acc: 0.5800 - val_loss: 1.0402 - val_acc: 0.6292
# Epoch 9/30
#  - 29s - loss: 1.1278 - acc: 0.6031 - val_loss: 1.0314 - val_acc: 0.6377
# Epoch 10/30
#  - 29s - loss: 1.0765 - acc: 0.6199 - val_loss: 0.9209 - val_acc: 0.6721
# Epoch 11/30
#  - 29s - loss: 1.0320 - acc: 0.6349 - val_loss: 0.9089 - val_acc: 0.6756
# Epoch 12/30
#  - 29s - loss: 0.9884 - acc: 0.6544 - val_loss: 0.9375 - val_acc: 0.6762
# Epoch 13/30
#  - 29s - loss: 0.9577 - acc: 0.6635 - val_loss: 0.7813 - val_acc: 0.7224
# Epoch 14/30
#  - 29s - loss: 0.9293 - acc: 0.6747 - val_loss: 1.0758 - val_acc: 0.6497
# Epoch 15/30
#  - 29s - loss: 0.8972 - acc: 0.6861 - val_loss: 0.8769 - val_acc: 0.7017
# Epoch 16/30
#  - 29s - loss: 0.8756 - acc: 0.6963 - val_loss: 0.8549 - val_acc: 0.7046
# Epoch 17/30
#  - 29s - loss: 0.8500 - acc: 0.7068 - val_loss: 0.7245 - val_acc: 0.7452
# Epoch 18/30
#  - 29s - loss: 0.8332 - acc: 0.7123 - val_loss: 0.8331 - val_acc: 0.7211
# Epoch 19/30
#  - 29s - loss: 0.8014 - acc: 0.7220 - val_loss: 0.7157 - val_acc: 0.7552
# Epoch 20/30
#  - 29s - loss: 0.7914 - acc: 0.7256 - val_loss: 0.6663 - val_acc: 0.7764
# Epoch 21/30
#  - 28s - loss: 0.7733 - acc: 0.7336 - val_loss: 0.8977 - val_acc: 0.7051
# Epoch 22/30
#  - 27s - loss: 0.7574 - acc: 0.7382 - val_loss: 0.8543 - val_acc: 0.7199
# Epoch 23/30
#  - 29s - loss: 0.7384 - acc: 0.7436 - val_loss: 0.8312 - val_acc: 0.7370
# Epoch 24/30
#  - 28s - loss: 0.7252 - acc: 0.7492 - val_loss: 0.6373 - val_acc: 0.7838
# Epoch 25/30
#  - 26s - loss: 0.7143 - acc: 0.7552 - val_loss: 0.7516 - val_acc: 0.7661
# Epoch 26/30
#  - 29s - loss: 0.7042 - acc: 0.7554 - val_loss: 0.7185 - val_acc: 0.7590
# Epoch 27/30
#  - 29s - loss: 0.6858 - acc: 0.7646 - val_loss: 0.6609 - val_acc: 0.7757
# Epoch 28/30
#  - 29s - loss: 0.6800 - acc: 0.7668 - val_loss: 0.5697 - val_acc: 0.8059
# Epoch 29/30
#  - 29s - loss: 0.6640 - acc: 0.7728 - val_loss: 0.6031 - val_acc: 0.7951
# Epoch 30/30
#  - 29s - loss: 0.6504 - acc: 0.7761 - val_loss: 0.6739 - val_acc: 0.7703
# ---------- Fold 2 ----------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 256)       295168
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 13, 13, 256)       590080
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 11, 11, 256)       590080
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 512)         1180160
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 3, 3, 512)         2359808
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4608)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 6,202,378
# Trainable params: 6,201,866
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/30
#  - 29s - loss: 2.0231 - acc: 0.2435 - val_loss: 4.1918 - val_acc: 0.1747
# Epoch 2/30
#  - 29s - loss: 1.7300 - acc: 0.3605 - val_loss: 1.5197 - val_acc: 0.4482
# Epoch 3/30
#  - 29s - loss: 1.5629 - acc: 0.4271 - val_loss: 1.3264 - val_acc: 0.5278
# Epoch 4/30
#  - 29s - loss: 1.4378 - acc: 0.4745 - val_loss: 1.6620 - val_acc: 0.4743
# Epoch 5/30
#  - 30s - loss: 1.3431 - acc: 0.5154 - val_loss: 1.8932 - val_acc: 0.4450
# Epoch 6/30
#  - 29s - loss: 1.2708 - acc: 0.5435 - val_loss: 1.4036 - val_acc: 0.5455
# Epoch 7/30
#  - 29s - loss: 1.2002 - acc: 0.5725 - val_loss: 1.1052 - val_acc: 0.6227
# Epoch 8/30
#  - 29s - loss: 1.1389 - acc: 0.5976 - val_loss: 0.9992 - val_acc: 0.6466
# Epoch 9/30
#  - 29s - loss: 1.0941 - acc: 0.6109 - val_loss: 1.0784 - val_acc: 0.6418
# Epoch 10/30
#  - 29s - loss: 1.0386 - acc: 0.6341 - val_loss: 1.0896 - val_acc: 0.6210
# Epoch 11/30
#  - 29s - loss: 1.0087 - acc: 0.6473 - val_loss: 0.8115 - val_acc: 0.7179
# Epoch 12/30
#  - 29s - loss: 0.9567 - acc: 0.6640 - val_loss: 0.7976 - val_acc: 0.7260
# Epoch 13/30
#  - 29s - loss: 0.9328 - acc: 0.6777 - val_loss: 0.9135 - val_acc: 0.6995
# Epoch 14/30
#  - 29s - loss: 0.8999 - acc: 0.6869 - val_loss: 0.8701 - val_acc: 0.7026
# Epoch 15/30
#  - 29s - loss: 0.8666 - acc: 0.6974 - val_loss: 0.7809 - val_acc: 0.7365
# Epoch 16/30
#  - 29s - loss: 0.8403 - acc: 0.7080 - val_loss: 0.8093 - val_acc: 0.7272
# Epoch 17/30
#  - 29s - loss: 0.8238 - acc: 0.7137 - val_loss: 0.8965 - val_acc: 0.7013
# Epoch 18/30
#  - 30s - loss: 0.8013 - acc: 0.7228 - val_loss: 0.7446 - val_acc: 0.7486
# Epoch 19/30
#  - 29s - loss: 0.7869 - acc: 0.7303 - val_loss: 0.7215 - val_acc: 0.7652
# Epoch 20/30
#  - 29s - loss: 0.7640 - acc: 0.7384 - val_loss: 0.7673 - val_acc: 0.7439
# Epoch 21/30
#  - 29s - loss: 0.7498 - acc: 0.7409 - val_loss: 0.6288 - val_acc: 0.7880
# Epoch 22/30
#  - 29s - loss: 0.7368 - acc: 0.7448 - val_loss: 0.6966 - val_acc: 0.7590
# Epoch 23/30
#  - 29s - loss: 0.7229 - acc: 0.7522 - val_loss: 0.7177 - val_acc: 0.7656
# Epoch 24/30
#  - 29s - loss: 0.7060 - acc: 0.7580 - val_loss: 0.6151 - val_acc: 0.7897
# Epoch 25/30
#  - 29s - loss: 0.6928 - acc: 0.7640 - val_loss: 1.0591 - val_acc: 0.6782
# Epoch 26/30
#  - 28s - loss: 0.6825 - acc: 0.7670 - val_loss: 0.6803 - val_acc: 0.7831
# Epoch 27/30
#  - 28s - loss: 0.6709 - acc: 0.7691 - val_loss: 0.6496 - val_acc: 0.7880
# Epoch 28/30
#  - 29s - loss: 0.6566 - acc: 0.7736 - val_loss: 0.6864 - val_acc: 0.7763
# Epoch 29/30
#  - 29s - loss: 0.6563 - acc: 0.7769 - val_loss: 0.5565 - val_acc: 0.8131
# Epoch 30/30
#  - 29s - loss: 0.6442 - acc: 0.7804 - val_loss: 0.6150 - val_acc: 0.7893
# ---------- Fold 3 ----------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 30, 30, 128)       3584
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 28, 28, 256)       295168
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 256)       590080
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 11, 11, 256)       590080
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 5, 5, 512)         1180160
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 3, 3, 512)         2359808
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4608)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 6,202,378
# Trainable params: 6,201,866
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/30
#  - 30s - loss: 2.0368 - acc: 0.2376 - val_loss: 2.2560 - val_acc: 0.2821
# Epoch 2/30
#  - 29s - loss: 1.7194 - acc: 0.3616 - val_loss: 1.6879 - val_acc: 0.4056
# Epoch 3/30
#  - 30s - loss: 1.5439 - acc: 0.4317 - val_loss: 1.8517 - val_acc: 0.4351
# Epoch 4/30
#  - 29s - loss: 1.4183 - acc: 0.4890 - val_loss: 1.2811 - val_acc: 0.5504
# Epoch 5/30
#  - 29s - loss: 1.3136 - acc: 0.5310 - val_loss: 1.3377 - val_acc: 0.5565
# Epoch 6/30
#  - 27s - loss: 1.2328 - acc: 0.5555 - val_loss: 1.1664 - val_acc: 0.6096
# Epoch 7/30
#  - 29s - loss: 1.1576 - acc: 0.5892 - val_loss: 1.0571 - val_acc: 0.6256
# Epoch 8/30
#  - 27s - loss: 1.1016 - acc: 0.6113 - val_loss: 1.2295 - val_acc: 0.5896
# Epoch 9/30
#  - 29s - loss: 1.0473 - acc: 0.6328 - val_loss: 0.9151 - val_acc: 0.6784
# Epoch 10/30
#  - 28s - loss: 1.0015 - acc: 0.6499 - val_loss: 1.1149 - val_acc: 0.6292
# Epoch 11/30
#  - 27s - loss: 0.9591 - acc: 0.6641 - val_loss: 0.9076 - val_acc: 0.6913
# Epoch 12/30
#  - 27s - loss: 0.9233 - acc: 0.6781 - val_loss: 0.7630 - val_acc: 0.7304
# Epoch 13/30
#  - 27s - loss: 0.9008 - acc: 0.6870 - val_loss: 0.9900 - val_acc: 0.6608
# Epoch 14/30
#  - 29s - loss: 0.8688 - acc: 0.6966 - val_loss: 0.8545 - val_acc: 0.7065
# Epoch 15/30
#  - 28s - loss: 0.8402 - acc: 0.7106 - val_loss: 0.8644 - val_acc: 0.7012
# Epoch 16/30
#  - 28s - loss: 0.8138 - acc: 0.7176 - val_loss: 0.7686 - val_acc: 0.7319
# Epoch 17/30
#  - 29s - loss: 0.7871 - acc: 0.7272 - val_loss: 0.7278 - val_acc: 0.7473
# Epoch 18/30
#  - 27s - loss: 0.7763 - acc: 0.7295 - val_loss: 0.9305 - val_acc: 0.7011
# Epoch 19/30
#  - 29s - loss: 0.7542 - acc: 0.7390 - val_loss: 0.6875 - val_acc: 0.7710
# Epoch 20/30
#  - 29s - loss: 0.7357 - acc: 0.7482 - val_loss: 0.6745 - val_acc: 0.7724
# Epoch 21/30
#  - 29s - loss: 0.7255 - acc: 0.7520 - val_loss: 0.6950 - val_acc: 0.7645
# Epoch 22/30
#  - 29s - loss: 0.7087 - acc: 0.7573 - val_loss: 0.6937 - val_acc: 0.7726
# Epoch 23/30
#  - 29s - loss: 0.6901 - acc: 0.7649 - val_loss: 0.6849 - val_acc: 0.7690
# Epoch 24/30
#  - 29s - loss: 0.6893 - acc: 0.7673 - val_loss: 0.6631 - val_acc: 0.7751
# Epoch 25/30
#  - 29s - loss: 0.6613 - acc: 0.7751 - val_loss: 0.6267 - val_acc: 0.7868
# Epoch 26/30
#  - 27s - loss: 0.6584 - acc: 0.7756 - val_loss: 0.7174 - val_acc: 0.7637
# Epoch 27/30
#  - 27s - loss: 0.6472 - acc: 0.7798 - val_loss: 0.6496 - val_acc: 0.7839
# Epoch 28/30
#  - 27s - loss: 0.6360 - acc: 0.7823 - val_loss: 0.6501 - val_acc: 0.7845
# Epoch 29/30
#  - 29s - loss: 0.6239 - acc: 0.7866 - val_loss: 0.5802 - val_acc: 0.8049
# Epoch 30/30
#  - 29s - loss: 0.6205 - acc: 0.7878 - val_loss: 0.6412 - val_acc: 0.7851
# ---------- Fold 4 ----------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 30, 30, 128)       3584
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 28, 28, 256)       295168
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 13, 13, 256)       590080
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 11, 11, 256)       590080
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 5, 5, 512)         1180160
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 3, 3, 512)         2359808
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4608)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 6,202,378
# Trainable params: 6,201,866
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/30
#  - 27s - loss: 1.9979 - acc: 0.2532 - val_loss: 3.7694 - val_acc: 0.1918
# Epoch 2/30
#  - 29s - loss: 1.7080 - acc: 0.3651 - val_loss: 1.5779 - val_acc: 0.4493
# Epoch 3/30
#  - 27s - loss: 1.5368 - acc: 0.4411 - val_loss: 1.9414 - val_acc: 0.3842
# Epoch 4/30
#  - 27s - loss: 1.4127 - acc: 0.4905 - val_loss: 1.2928 - val_acc: 0.5497
# Epoch 5/30
#  - 29s - loss: 1.3161 - acc: 0.5240 - val_loss: 1.2233 - val_acc: 0.5727
# Epoch 6/30
#  - 29s - loss: 1.2278 - acc: 0.5613 - val_loss: 1.1640 - val_acc: 0.6151
# Epoch 7/30
#  - 28s - loss: 1.1547 - acc: 0.5929 - val_loss: 1.4070 - val_acc: 0.5563
# Epoch 8/30
#  - 27s - loss: 1.0963 - acc: 0.6135 - val_loss: 1.1013 - val_acc: 0.6294
# Epoch 9/30
#  - 28s - loss: 1.0389 - acc: 0.6331 - val_loss: 1.3591 - val_acc: 0.5830
# Epoch 10/30
#  - 29s - loss: 0.9958 - acc: 0.6478 - val_loss: 1.2553 - val_acc: 0.6125
# Epoch 11/30
#  - 27s - loss: 0.9596 - acc: 0.6636 - val_loss: 0.8869 - val_acc: 0.6969
# Epoch 12/30
#  - 28s - loss: 0.9249 - acc: 0.6760 - val_loss: 0.9574 - val_acc: 0.6941
# Epoch 13/30
#  - 27s - loss: 0.8925 - acc: 0.6871 - val_loss: 0.8953 - val_acc: 0.7039
# Epoch 14/30
#  - 29s - loss: 0.8635 - acc: 0.7006 - val_loss: 0.9444 - val_acc: 0.7043
# Epoch 15/30
#  - 28s - loss: 0.8428 - acc: 0.7078 - val_loss: 0.6760 - val_acc: 0.7684
# Epoch 16/30
#  - 26s - loss: 0.8149 - acc: 0.7186 - val_loss: 0.9066 - val_acc: 0.7009
# Epoch 17/30
#  - 27s - loss: 0.8075 - acc: 0.7214 - val_loss: 0.8911 - val_acc: 0.7146
# Epoch 18/30
#  - 30s - loss: 0.7864 - acc: 0.7284 - val_loss: 0.6635 - val_acc: 0.7777
# Epoch 19/30
#  - 29s - loss: 0.7637 - acc: 0.7333 - val_loss: 0.6503 - val_acc: 0.7815
# Epoch 20/30
#  - 29s - loss: 0.7494 - acc: 0.7422 - val_loss: 0.8651 - val_acc: 0.7273
# Epoch 21/30
#  - 29s - loss: 0.7418 - acc: 0.7435 - val_loss: 0.6663 - val_acc: 0.7756
# Epoch 22/30
#  - 29s - loss: 0.7175 - acc: 0.7530 - val_loss: 0.5991 - val_acc: 0.7988
# Epoch 23/30
#  - 29s - loss: 0.7094 - acc: 0.7559 - val_loss: 0.7231 - val_acc: 0.7594
# Epoch 24/30
#  - 28s - loss: 0.6884 - acc: 0.7650 - val_loss: 0.5798 - val_acc: 0.8072
# Epoch 25/30
#  - 27s - loss: 0.6906 - acc: 0.7636 - val_loss: 0.6721 - val_acc: 0.7804
# Epoch 26/30
#  - 27s - loss: 0.6677 - acc: 0.7711 - val_loss: 0.6374 - val_acc: 0.7855
# Epoch 27/30
#  - 27s - loss: 0.6574 - acc: 0.7749 - val_loss: 0.6263 - val_acc: 0.7935
# Epoch 28/30
#  - 27s - loss: 0.6511 - acc: 0.7751 - val_loss: 0.5681 - val_acc: 0.8123
# Epoch 29/30
#  - 29s - loss: 0.6409 - acc: 0.7794 - val_loss: 0.5695 - val_acc: 0.8118
# Epoch 30/30
#  - 29s - loss: 0.6327 - acc: 0.7834 - val_loss: 0.7547 - val_acc: 0.7609
# ---------- Fold 5 ----------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 30, 30, 128)       3584
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 28, 28, 256)       295168
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 13, 13, 256)       590080
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 11, 11, 256)       590080
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 5, 5, 512)         1180160
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 3, 3, 512)         2359808
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4608)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 6,202,378
# Trainable params: 6,201,866
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/30
#  - 28s - loss: 2.0199 - acc: 0.2408 - val_loss: 2.2504 - val_acc: 0.2344
# Epoch 2/30
#  - 27s - loss: 1.7168 - acc: 0.3637 - val_loss: 1.9092 - val_acc: 0.3917
# Epoch 3/30
#  - 27s - loss: 1.5503 - acc: 0.4300 - val_loss: 1.5767 - val_acc: 0.4378
# Epoch 4/30
#  - 28s - loss: 1.4284 - acc: 0.4773 - val_loss: 1.5765 - val_acc: 0.4697
# Epoch 5/30
#  - 29s - loss: 1.3299 - acc: 0.5223 - val_loss: 1.5196 - val_acc: 0.4923
# Epoch 6/30
#  - 29s - loss: 1.2497 - acc: 0.5558 - val_loss: 1.2368 - val_acc: 0.5779
# Epoch 7/30
#  - 29s - loss: 1.1805 - acc: 0.5808 - val_loss: 1.2273 - val_acc: 0.5882
# Epoch 8/30
#  - 29s - loss: 1.1272 - acc: 0.5996 - val_loss: 1.2766 - val_acc: 0.5971
# Epoch 9/30
#  - 29s - loss: 1.0781 - acc: 0.6179 - val_loss: 0.9110 - val_acc: 0.6798
# Epoch 10/30
#  - 29s - loss: 1.0391 - acc: 0.6353 - val_loss: 0.9064 - val_acc: 0.6877
# Epoch 11/30
#  - 29s - loss: 0.9911 - acc: 0.6504 - val_loss: 1.0207 - val_acc: 0.6370
# Epoch 12/30
#  - 29s - loss: 0.9601 - acc: 0.6634 - val_loss: 0.8911 - val_acc: 0.6963
# Epoch 13/30
#  - 29s - loss: 0.9233 - acc: 0.6752 - val_loss: 1.1403 - val_acc: 0.6356
# Epoch 14/30
#  - 29s - loss: 0.8971 - acc: 0.6858 - val_loss: 0.7686 - val_acc: 0.7377
# Epoch 15/30
#  - 29s - loss: 0.8753 - acc: 0.6950 - val_loss: 0.7967 - val_acc: 0.7226
# Epoch 16/30
#  - 29s - loss: 0.8442 - acc: 0.7081 - val_loss: 0.7757 - val_acc: 0.7220
# Epoch 17/30
#  - 29s - loss: 0.8244 - acc: 0.7123 - val_loss: 0.7936 - val_acc: 0.7334
# Epoch 18/30
#  - 29s - loss: 0.7977 - acc: 0.7231 - val_loss: 0.8167 - val_acc: 0.7307
# Epoch 19/30
#  - 30s - loss: 0.7846 - acc: 0.7283 - val_loss: 0.7296 - val_acc: 0.7457
# Epoch 20/30
#  - 29s - loss: 0.7632 - acc: 0.7369 - val_loss: 0.7782 - val_acc: 0.7357
# Epoch 21/30
#  - 29s - loss: 0.7528 - acc: 0.7406 - val_loss: 0.6625 - val_acc: 0.7755
# Epoch 22/30
#  - 29s - loss: 0.7309 - acc: 0.7460 - val_loss: 0.7273 - val_acc: 0.7629
# Epoch 23/30
#  - 29s - loss: 0.7198 - acc: 0.7530 - val_loss: 0.8587 - val_acc: 0.7209
# Epoch 24/30
#  - 29s - loss: 0.7068 - acc: 0.7590 - val_loss: 0.7584 - val_acc: 0.7489
# Epoch 25/30
#  - 29s - loss: 0.6924 - acc: 0.7645 - val_loss: 0.7691 - val_acc: 0.7406
# Epoch 26/30
#  - 29s - loss: 0.6760 - acc: 0.7704 - val_loss: 0.6844 - val_acc: 0.7746
# Epoch 27/30
#  - 29s - loss: 0.6700 - acc: 0.7695 - val_loss: 0.5687 - val_acc: 0.8039
# Epoch 28/30
#  - 29s - loss: 0.6507 - acc: 0.7782 - val_loss: 0.6536 - val_acc: 0.7798
# Epoch 29/30
#  - 29s - loss: 0.6427 - acc: 0.7792 - val_loss: 0.7236 - val_acc: 0.7639
# Epoch 30/30
#  - 29s - loss: 0.6356 - acc: 0.7826 - val_loss: 0.6919 - val_acc: 0.7697
# [0.7703, 0.7887, 0.7864, 0.7617, 0.7692]
# Average scores = 0.7752600000000001

# %%
# As it is shown in the result, the average of the accuracies for 5-fold is 77%. In simple hold-out validation 
# we got 80% accuracy which is more than the k-fold result. It means that we chose a good random 
# validation set by chance. If we increase the number of epochs, or shuffle the data differently
#the results would be different. (I did not use the same random shuffling of the data for both
#simple holdout and k-fold techniques.)
