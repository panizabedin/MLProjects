# %%
from keras.datasets import cifar10
import tensorflow as tf
from tensorflow import keras
import numpy as np
import math
import matplotlib.pyplot as plt
from keras.utils.np_utils import to_categorical
from keras import layers
from keras import models
from keras import optimizers
from time import time as t
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
# loading CIFAR10 data
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# normalizing data
train_images = train_images.reshape((50000, 32, 32, 3)) / 255.0
test_images = test_images.reshape((10000, 32, 32, 3)) / 255.0

# %%
# m is the number of training examples
m = train_images.shape[0]
shuffled_indices = np.random.permutation(m)
# shuffling the training data randomely
train_images_shuffled = train_images[shuffled_indices]
train_labels_shuffled = train_labels[shuffled_indices]

# setting 0.20 of the training data to validation set randomly


# one hot encoding of the labels
train_labels_shuffled = to_categorical(train_labels_shuffled, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)

# %% [markdown]
# ## K - Fold Validation

# %%
# training function for each fold using data augmentation 
def fold(model, training_set, training_labels, validation_set, validation_set_labels):
    train_datagen = ImageDataGenerator(
        width_shift_range=0.2,  # randomly shift images horizontally 
        height_shift_range=0.2,  # randomly shift images vertically 
        shear_range=0.2,        # randomly shear images
        horizontal_flip=True)  # flip images horizontally

    validation_datagen = ImageDataGenerator()

    train_generator = train_datagen.flow(training_set, training_labels, batch_size=32)
    validation_generator = validation_datagen.flow(validation_set, validation_set_labels, batch_size=32)
    history_dataaug_model5 = model.fit_generator(train_generator, validation_data=validation_generator,
                                                 validation_steps=len(training_set) / 32,
                                                 steps_per_epoch=len(training_set) / 32,
                                                 epochs=30, verbose=2)

    score = model.evaluate(validation_set, validation_set_labels, batch_size=128, verbose=0)
    return score[1]

# %%
# Using the winner architecture (arch 5) for training the data in each fold and storing the score 
def k_fold_validation(training_set, training_labels, n):
    # scores stores the accuracy of 5 folds
    scores = []

   
    fold_size = math.floor(len(training_set) / n)
    for i in range(n):
        print("---------- Fold", i+1, "----------")
        fold_validation_set = training_set[i * fold_size:i * fold_size + fold_size]
        fold_validation_set_labels = training_labels[i * fold_size:i * fold_size + fold_size]
        fold_training_set = np.delete(training_set, slice(i * fold_size, i * fold_size + fold_size), axis=0)
        fold_training_labels = np.delete(training_labels, slice(i * fold_size, i * fold_size + fold_size), axis=0)
        model_5 = models.Sequential()
        model_5.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
        model_5.add(layers.Conv2D(64, (3, 3), activation='relu'))
        model_5.add(layers.Conv2D(64, (3, 3), activation='relu', strides=2))
        model_5.add(layers.Conv2D(64, (3, 3), activation='relu'))
        model_5.add(layers.Conv2D(128, (3, 3), activation='relu', strides=2))
        model_5.add(layers.Conv2D(128, (3, 3), activation='relu'))
        model_5.add(layers.Flatten())
        model_5.add(layers.Dropout(0.5))
        model_5.add(layers.Dense(64, activation='relu'))
        model_5.add(layers.normalization.BatchNormalization())
        model_5.add(layers.Dense(10, activation='softmax'))

        model_5.summary()

        model_5.compile(optimizer='rmsprop',
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])
        # score of each fold
        s = fold(model_5, fold_training_set, fold_training_labels, fold_validation_set, fold_validation_set_labels)

        scores.append(s)

    print(scores)
    
    # computes the average of 5 accuracies for 5 folds
    scores_average = np.average(scores)
    print("Average score =", scores_average)


k_fold_validation(train_images_shuffled, train_labels_shuffled, 5)
# Out:
# ---------- Fold 1 ----------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 5, 5, 128)         73856
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 3, 3, 128)         147584
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1152)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                73792
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                650
# =================================================================
# Total params: 389,386
# Trainable params: 389,258
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/30
#  - 13s - loss: 1.8359 - acc: 0.3049 - val_loss: 1.8616 - val_acc: 0.3753
# Epoch 2/30
#  - 13s - loss: 1.5241 - acc: 0.4416 - val_loss: 1.4408 - val_acc: 0.4993
# Epoch 3/30
#  - 13s - loss: 1.3632 - acc: 0.5084 - val_loss: 1.5480 - val_acc: 0.4776
# Epoch 4/30
#  - 13s - loss: 1.2546 - acc: 0.5498 - val_loss: 1.0926 - val_acc: 0.6037
# Epoch 5/30
#  - 13s - loss: 1.1778 - acc: 0.5810 - val_loss: 1.2169 - val_acc: 0.5928
# Epoch 6/30
#  - 13s - loss: 1.1174 - acc: 0.6029 - val_loss: 1.0421 - val_acc: 0.6330
# Epoch 7/30
#  - 13s - loss: 1.0700 - acc: 0.6250 - val_loss: 1.3384 - val_acc: 0.5688
# Epoch 8/30
#  - 13s - loss: 1.0215 - acc: 0.6390 - val_loss: 0.9644 - val_acc: 0.6698
# Epoch 9/30
#  - 13s - loss: 0.9868 - acc: 0.6552 - val_loss: 0.8689 - val_acc: 0.6975
# Epoch 10/30
#  - 13s - loss: 0.9672 - acc: 0.6626 - val_loss: 0.9117 - val_acc: 0.6793
# Epoch 11/30
#  - 13s - loss: 0.9317 - acc: 0.6773 - val_loss: 0.8195 - val_acc: 0.7102
# Epoch 12/30
#  - 13s - loss: 0.9104 - acc: 0.6841 - val_loss: 0.8392 - val_acc: 0.7097
# Epoch 13/30
#  - 13s - loss: 0.8956 - acc: 0.6921 - val_loss: 0.7118 - val_acc: 0.7503
# Epoch 14/30
#  - 13s - loss: 0.8766 - acc: 0.6971 - val_loss: 0.7531 - val_acc: 0.7385
# Epoch 15/30
#  - 13s - loss: 0.8590 - acc: 0.7044 - val_loss: 0.8357 - val_acc: 0.7176
# Epoch 16/30
#  - 13s - loss: 0.8472 - acc: 0.7076 - val_loss: 0.7028 - val_acc: 0.7564
# Epoch 17/30
#  - 13s - loss: 0.8305 - acc: 0.7146 - val_loss: 0.6604 - val_acc: 0.7721
# Epoch 18/30
#  - 13s - loss: 0.8082 - acc: 0.7227 - val_loss: 0.6874 - val_acc: 0.7682
# Epoch 19/30
#  - 13s - loss: 0.8015 - acc: 0.7224 - val_loss: 0.7028 - val_acc: 0.7573
# Epoch 20/30
#  - 13s - loss: 0.7863 - acc: 0.7297 - val_loss: 0.7548 - val_acc: 0.7450
# Epoch 21/30
#  - 13s - loss: 0.7784 - acc: 0.7332 - val_loss: 0.6341 - val_acc: 0.7790
# Epoch 22/30
#  - 13s - loss: 0.7701 - acc: 0.7355 - val_loss: 0.6800 - val_acc: 0.7680
# Epoch 23/30
#  - 13s - loss: 0.7563 - acc: 0.7394 - val_loss: 0.6558 - val_acc: 0.7805
# Epoch 24/30
#  - 13s - loss: 0.7447 - acc: 0.7464 - val_loss: 0.6511 - val_acc: 0.7784
# Epoch 25/30
#  - 13s - loss: 0.7424 - acc: 0.7460 - val_loss: 0.6816 - val_acc: 0.7671
# Epoch 26/30
#  - 13s - loss: 0.7315 - acc: 0.7498 - val_loss: 0.6447 - val_acc: 0.7769
# Epoch 27/30
#  - 13s - loss: 0.7249 - acc: 0.7528 - val_loss: 0.6841 - val_acc: 0.7701
# Epoch 28/30
#  - 13s - loss: 0.7118 - acc: 0.7585 - val_loss: 0.7681 - val_acc: 0.7389
# Epoch 29/30
#  - 13s - loss: 0.7128 - acc: 0.7571 - val_loss: 0.7431 - val_acc: 0.7525
# Epoch 30/30
#  - 13s - loss: 0.7058 - acc: 0.7600 - val_loss: 0.6207 - val_acc: 0.7868
# ---------- Fold 2 ----------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 5, 5, 128)         73856
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 3, 3, 128)         147584
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1152)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                73792
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                650
# =================================================================
# Total params: 389,386
# Trainable params: 389,258
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/30
#  - 13s - loss: 1.8392 - acc: 0.3052 - val_loss: 1.9415 - val_acc: 0.3731
# Epoch 2/30
#  - 13s - loss: 1.5201 - acc: 0.4430 - val_loss: 1.3564 - val_acc: 0.5193
# Epoch 3/30
#  - 13s - loss: 1.3467 - acc: 0.5145 - val_loss: 1.1348 - val_acc: 0.5979
# Epoch 4/30
#  - 13s - loss: 1.2217 - acc: 0.5652 - val_loss: 1.0792 - val_acc: 0.6259
# Epoch 5/30
#  - 13s - loss: 1.1395 - acc: 0.5957 - val_loss: 1.2964 - val_acc: 0.5970
# Epoch 6/30
#  - 13s - loss: 1.0756 - acc: 0.6218 - val_loss: 1.0981 - val_acc: 0.6248
# Epoch 7/30
#  - 13s - loss: 1.0264 - acc: 0.6385 - val_loss: 1.3538 - val_acc: 0.5825
# Epoch 8/30
#  - 13s - loss: 0.9949 - acc: 0.6509 - val_loss: 0.9913 - val_acc: 0.6535
# Epoch 9/30
#  - 13s - loss: 0.9590 - acc: 0.6657 - val_loss: 0.9550 - val_acc: 0.6836
# Epoch 10/30
#  - 13s - loss: 0.9358 - acc: 0.6745 - val_loss: 0.7470 - val_acc: 0.7401
# Epoch 11/30
#  - 13s - loss: 0.9086 - acc: 0.6845 - val_loss: 0.8049 - val_acc: 0.7128
# Epoch 12/30
#  - 13s - loss: 0.8860 - acc: 0.6907 - val_loss: 0.8793 - val_acc: 0.7116
# Epoch 13/30
#  - 13s - loss: 0.8638 - acc: 0.7017 - val_loss: 0.7899 - val_acc: 0.7319
# Epoch 14/30
#  - 13s - loss: 0.8442 - acc: 0.7078 - val_loss: 0.7466 - val_acc: 0.7475
# Epoch 15/30
#  - 13s - loss: 0.8337 - acc: 0.7127 - val_loss: 0.7753 - val_acc: 0.7247
# Epoch 16/30
#  - 13s - loss: 0.8164 - acc: 0.7175 - val_loss: 0.6923 - val_acc: 0.7674
# Epoch 17/30
#  - 13s - loss: 0.8068 - acc: 0.7218 - val_loss: 0.6609 - val_acc: 0.7683
# Epoch 18/30
#  - 13s - loss: 0.7953 - acc: 0.7276 - val_loss: 0.9523 - val_acc: 0.6915
# Epoch 19/30
#  - 13s - loss: 0.7849 - acc: 0.7266 - val_loss: 0.7468 - val_acc: 0.7558
# Epoch 20/30
#  - 13s - loss: 0.7727 - acc: 0.7347 - val_loss: 0.7587 - val_acc: 0.7383
# Epoch 21/30
#  - 13s - loss: 0.7585 - acc: 0.7381 - val_loss: 0.6854 - val_acc: 0.7654
# Epoch 22/30
#  - 13s - loss: 0.7585 - acc: 0.7393 - val_loss: 0.6737 - val_acc: 0.7688
# Epoch 23/30
#  - 13s - loss: 0.7419 - acc: 0.7449 - val_loss: 0.8646 - val_acc: 0.7284
# Epoch 24/30
#  - 13s - loss: 0.7368 - acc: 0.7482 - val_loss: 0.7694 - val_acc: 0.7408
# Epoch 25/30
#  - 13s - loss: 0.7245 - acc: 0.7521 - val_loss: 0.6981 - val_acc: 0.7617
# Epoch 26/30
#  - 13s - loss: 0.7215 - acc: 0.7508 - val_loss: 0.6297 - val_acc: 0.7850
# Epoch 27/30
#  - 13s - loss: 0.7144 - acc: 0.7541 - val_loss: 0.8418 - val_acc: 0.7350
# Epoch 28/30
#  - 13s - loss: 0.7130 - acc: 0.7534 - val_loss: 0.6090 - val_acc: 0.7932
# Epoch 29/30
#  - 13s - loss: 0.7005 - acc: 0.7599 - val_loss: 0.5663 - val_acc: 0.8090
# Epoch 30/30
#  - 13s - loss: 0.6919 - acc: 0.7652 - val_loss: 0.7083 - val_acc: 0.7668
# ---------- Fold 3 ----------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_31 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 5, 5, 128)         73856
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 3, 3, 128)         147584
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1152)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                73792
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64)                256
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                650
# =================================================================
# Total params: 389,386
# Trainable params: 389,258
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/30
#  - 14s - loss: 1.8562 - acc: 0.2936 - val_loss: 1.7615 - val_acc: 0.3798
# Epoch 2/30
#  - 13s - loss: 1.5246 - acc: 0.4388 - val_loss: 1.4352 - val_acc: 0.4930
# Epoch 3/30
#  - 13s - loss: 1.3628 - acc: 0.5093 - val_loss: 1.1862 - val_acc: 0.5797
# Epoch 4/30
#  - 13s - loss: 1.2490 - acc: 0.5562 - val_loss: 1.2594 - val_acc: 0.5782
# Epoch 5/30
#  - 13s - loss: 1.1683 - acc: 0.5853 - val_loss: 1.1360 - val_acc: 0.5999
# Epoch 6/30
#  - 13s - loss: 1.0982 - acc: 0.6104 - val_loss: 0.9581 - val_acc: 0.6613
# Epoch 7/30
#  - 13s - loss: 1.0545 - acc: 0.6271 - val_loss: 0.9595 - val_acc: 0.6601
# Epoch 8/30
#  - 13s - loss: 1.0093 - acc: 0.6458 - val_loss: 0.7848 - val_acc: 0.7307
# Epoch 9/30
#  - 13s - loss: 0.9706 - acc: 0.6613 - val_loss: 0.9862 - val_acc: 0.6707
# Epoch 10/30
#  - 13s - loss: 0.9482 - acc: 0.6692 - val_loss: 0.8525 - val_acc: 0.7045
# Epoch 11/30
#  - 13s - loss: 0.9195 - acc: 0.6820 - val_loss: 0.8357 - val_acc: 0.7142
# Epoch 12/30
#  - 13s - loss: 0.9005 - acc: 0.6875 - val_loss: 0.8201 - val_acc: 0.7171
# Epoch 13/30
#  - 13s - loss: 0.8777 - acc: 0.6972 - val_loss: 0.6962 - val_acc: 0.7562
# Epoch 14/30
#  - 13s - loss: 0.8652 - acc: 0.7015 - val_loss: 0.8609 - val_acc: 0.7153
# Epoch 15/30
#  - 13s - loss: 0.8408 - acc: 0.7095 - val_loss: 0.7318 - val_acc: 0.7454
# Epoch 16/30
#  - 13s - loss: 0.8250 - acc: 0.7169 - val_loss: 0.6588 - val_acc: 0.7673
# Epoch 17/30
#  - 13s - loss: 0.8177 - acc: 0.7179 - val_loss: 0.8291 - val_acc: 0.7269
# Epoch 18/30
#  - 13s - loss: 0.8021 - acc: 0.7233 - val_loss: 0.6930 - val_acc: 0.7599
# Epoch 19/30
#  - 13s - loss: 0.7908 - acc: 0.7265 - val_loss: 0.6398 - val_acc: 0.7872
# Epoch 20/30
#  - 13s - loss: 0.7772 - acc: 0.7332 - val_loss: 0.7108 - val_acc: 0.7557
# Epoch 21/30
#  - 13s - loss: 0.7700 - acc: 0.7336 - val_loss: 0.7040 - val_acc: 0.7632
# Epoch 22/30
#  - 13s - loss: 0.7605 - acc: 0.7409 - val_loss: 0.6848 - val_acc: 0.7695
# Epoch 23/30
#  - 13s - loss: 0.7491 - acc: 0.7423 - val_loss: 0.6600 - val_acc: 0.7842
# Epoch 24/30
#  - 13s - loss: 0.7439 - acc: 0.7455 - val_loss: 0.7484 - val_acc: 0.7435
# Epoch 25/30
#  - 13s - loss: 0.7325 - acc: 0.7488 - val_loss: 0.6860 - val_acc: 0.7748
# Epoch 26/30
#  - 13s - loss: 0.7284 - acc: 0.7506 - val_loss: 0.7167 - val_acc: 0.7670
# Epoch 27/30
#  - 13s - loss: 0.7202 - acc: 0.7547 - val_loss: 0.5857 - val_acc: 0.8005
# Epoch 28/30
#  - 13s - loss: 0.7102 - acc: 0.7563 - val_loss: 0.6854 - val_acc: 0.7656
# Epoch 29/30
#  - 13s - loss: 0.7064 - acc: 0.7592 - val_loss: 0.7977 - val_acc: 0.7441
# Epoch 30/30
#  - 13s - loss: 0.6978 - acc: 0.7623 - val_loss: 0.6327 - val_acc: 0.7927
# ---------- Fold 4 ----------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_37 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 5, 5, 128)         73856
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 3, 3, 128)         147584
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1152)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                73792
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64)                256
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                650
# =================================================================
# Total params: 389,386
# Trainable params: 389,258
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/30
#  - 14s - loss: 1.8273 - acc: 0.3102 - val_loss: 2.7988 - val_acc: 0.2784
# Epoch 2/30
#  - 13s - loss: 1.4982 - acc: 0.4542 - val_loss: 1.2338 - val_acc: 0.5442
# Epoch 3/30
#  - 13s - loss: 1.3319 - acc: 0.5179 - val_loss: 1.8712 - val_acc: 0.4238
# Epoch 4/30
#  - 13s - loss: 1.2217 - acc: 0.5627 - val_loss: 1.0430 - val_acc: 0.6268
# Epoch 5/30
#  - 13s - loss: 1.1512 - acc: 0.5921 - val_loss: 1.0176 - val_acc: 0.6419
# Epoch 6/30
#  - 13s - loss: 1.0890 - acc: 0.6115 - val_loss: 1.1467 - val_acc: 0.6231
# Epoch 7/30
#  - 13s - loss: 1.0393 - acc: 0.6343 - val_loss: 0.8820 - val_acc: 0.6914
# Epoch 8/30
#  - 13s - loss: 1.0014 - acc: 0.6482 - val_loss: 0.9874 - val_acc: 0.6698
# Epoch 9/30
#  - 13s - loss: 0.9644 - acc: 0.6630 - val_loss: 0.9357 - val_acc: 0.6818
# Epoch 10/30
#  - 13s - loss: 0.9230 - acc: 0.6795 - val_loss: 0.9304 - val_acc: 0.6824
# Epoch 11/30
#  - 13s - loss: 0.9054 - acc: 0.6871 - val_loss: 0.8888 - val_acc: 0.6984
# Epoch 12/30
#  - 13s - loss: 0.8827 - acc: 0.6931 - val_loss: 0.7154 - val_acc: 0.7548
# Epoch 13/30
#  - 13s - loss: 0.8593 - acc: 0.7032 - val_loss: 0.7050 - val_acc: 0.7538
# Epoch 14/30
#  - 13s - loss: 0.8419 - acc: 0.7100 - val_loss: 0.9133 - val_acc: 0.7059
# Epoch 15/30
#  - 13s - loss: 0.8253 - acc: 0.7150 - val_loss: 0.7099 - val_acc: 0.7519
# Epoch 16/30
#  - 13s - loss: 0.8055 - acc: 0.7229 - val_loss: 0.6712 - val_acc: 0.7713
# Epoch 17/30
#  - 13s - loss: 0.7993 - acc: 0.7239 - val_loss: 0.7405 - val_acc: 0.7549
# Epoch 18/30
#  - 13s - loss: 0.7817 - acc: 0.7316 - val_loss: 0.7875 - val_acc: 0.7380
# Epoch 19/30
#  - 13s - loss: 0.7653 - acc: 0.7371 - val_loss: 0.6521 - val_acc: 0.7827
# Epoch 20/30
#  - 13s - loss: 0.7616 - acc: 0.7381 - val_loss: 0.7544 - val_acc: 0.7465
# Epoch 21/30
#  - 13s - loss: 0.7495 - acc: 0.7436 - val_loss: 0.6611 - val_acc: 0.7698
# Epoch 22/30
#  - 13s - loss: 0.7366 - acc: 0.7514 - val_loss: 0.8066 - val_acc: 0.7296
# Epoch 23/30
#  - 13s - loss: 0.7370 - acc: 0.7483 - val_loss: 0.7152 - val_acc: 0.7584
# Epoch 24/30
#  - 13s - loss: 0.7197 - acc: 0.7545 - val_loss: 0.6801 - val_acc: 0.7771
# Epoch 25/30
#  - 13s - loss: 0.7163 - acc: 0.7556 - val_loss: 0.7269 - val_acc: 0.7547
# Epoch 26/30
#  - 13s - loss: 0.7101 - acc: 0.7565 - val_loss: 0.7185 - val_acc: 0.7590
# Epoch 27/30
#  - 13s - loss: 0.6996 - acc: 0.7630 - val_loss: 0.5862 - val_acc: 0.7949
# Epoch 28/30
#  - 13s - loss: 0.6895 - acc: 0.7632 - val_loss: 0.6626 - val_acc: 0.7842
# Epoch 29/30
#  - 13s - loss: 0.6911 - acc: 0.7626 - val_loss: 0.7885 - val_acc: 0.7583
# Epoch 30/30
#  - 13s - loss: 0.6796 - acc: 0.7695 - val_loss: 0.6012 - val_acc: 0.7994
# ---------- Fold 5 ----------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_43 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 5, 5, 128)         73856
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 3, 3, 128)         147584
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1152)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                73792
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                650
# =================================================================
# Total params: 389,386
# Trainable params: 389,258
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/30
#  - 14s - loss: 1.8384 - acc: 0.3090 - val_loss: 2.1090 - val_acc: 0.3194
# Epoch 2/30
#  - 13s - loss: 1.5024 - acc: 0.4529 - val_loss: 1.5680 - val_acc: 0.4669
# Epoch 3/30
#  - 13s - loss: 1.3415 - acc: 0.5181 - val_loss: 1.7410 - val_acc: 0.4736
# Epoch 4/30
#  - 13s - loss: 1.2254 - acc: 0.5626 - val_loss: 1.3180 - val_acc: 0.5902
# Epoch 5/30
#  - 13s - loss: 1.1443 - acc: 0.5946 - val_loss: 1.1981 - val_acc: 0.5916
# Epoch 6/30
#  - 13s - loss: 1.0799 - acc: 0.6180 - val_loss: 0.9519 - val_acc: 0.6732
# Epoch 7/30
#  - 13s - loss: 1.0351 - acc: 0.6368 - val_loss: 1.0937 - val_acc: 0.6581
# Epoch 8/30
#  - 13s - loss: 0.9966 - acc: 0.6535 - val_loss: 0.8675 - val_acc: 0.6957
# Epoch 9/30
#  - 13s - loss: 0.9596 - acc: 0.6626 - val_loss: 0.8832 - val_acc: 0.7025
# Epoch 10/30
#  - 13s - loss: 0.9299 - acc: 0.6756 - val_loss: 1.0939 - val_acc: 0.6397
# Epoch 11/30
#  - 13s - loss: 0.9109 - acc: 0.6820 - val_loss: 0.8837 - val_acc: 0.6954
# Epoch 12/30
#  - 13s - loss: 0.8867 - acc: 0.6944 - val_loss: 0.7907 - val_acc: 0.7291
# Epoch 13/30
#  - 13s - loss: 0.8612 - acc: 0.7016 - val_loss: 0.6988 - val_acc: 0.7585
# Epoch 14/30
#  - 13s - loss: 0.8497 - acc: 0.7079 - val_loss: 0.7853 - val_acc: 0.7301
# Epoch 15/30
#  - 13s - loss: 0.8337 - acc: 0.7123 - val_loss: 0.8078 - val_acc: 0.7339
# Epoch 16/30
#  - 13s - loss: 0.8208 - acc: 0.7159 - val_loss: 0.6769 - val_acc: 0.7670
# Epoch 17/30
#  - 13s - loss: 0.7987 - acc: 0.7252 - val_loss: 0.8651 - val_acc: 0.7229
# Epoch 18/30
#  - 13s - loss: 0.7952 - acc: 0.7279 - val_loss: 1.0634 - val_acc: 0.6714
# Epoch 19/30
#  - 13s - loss: 0.7790 - acc: 0.7310 - val_loss: 0.6904 - val_acc: 0.7638
# Epoch 20/30
#  - 13s - loss: 0.7659 - acc: 0.7380 - val_loss: 0.5960 - val_acc: 0.7905
# Epoch 21/30
#  - 13s - loss: 0.7596 - acc: 0.7386 - val_loss: 0.7708 - val_acc: 0.7648
# Epoch 22/30
#  - 13s - loss: 0.7511 - acc: 0.7442 - val_loss: 0.7383 - val_acc: 0.7561
# Epoch 23/30
#  - 13s - loss: 0.7457 - acc: 0.7456 - val_loss: 0.5816 - val_acc: 0.7986
# Epoch 24/30
#  - 13s - loss: 0.7306 - acc: 0.7512 - val_loss: 0.6438 - val_acc: 0.7900
# Epoch 25/30
#  - 13s - loss: 0.7208 - acc: 0.7535 - val_loss: 0.6669 - val_acc: 0.7742
# Epoch 26/30
#  - 13s - loss: 0.7146 - acc: 0.7564 - val_loss: 0.6679 - val_acc: 0.7804
# Epoch 27/30
#  - 13s - loss: 0.7067 - acc: 0.7591 - val_loss: 0.7046 - val_acc: 0.7671
# Epoch 28/30
#  - 13s - loss: 0.7026 - acc: 0.7602 - val_loss: 0.6463 - val_acc: 0.7882
# Epoch 29/30
#  - 13s - loss: 0.6914 - acc: 0.7636 - val_loss: 0.5889 - val_acc: 0.7986
# Epoch 30/30
#  - 13s - loss: 0.6948 - acc: 0.7611 - val_loss: 0.6894 - val_acc: 0.7784
# [0.7869, 0.767, 0.7929, 0.7989, 0.7789]
# Average scores = 0.7849200000000001

# %%
# As it is shown in the result, the average of the accuracies for 5-fold is 78%. In simple hold-out validation 
# we also got 78% accuracy which is similar to the k-fold result. If we increase the number of epochs, 
# their difference may be increased.
